# %%
#ques 1 and 2

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
#ques 3

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
#ques4

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
#ques 5
#Largest Selling region is west

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
#ques 6

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
#ques 7

# %% [markdown]
# ![image.png](data:image/png;base64,...)
