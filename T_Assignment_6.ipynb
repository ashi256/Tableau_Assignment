# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
#3

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
#3

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
#4

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
#5

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
#6

# %% [markdown]
# ![image.png](data:image/png;base64,...)
